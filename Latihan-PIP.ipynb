# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL ="https://www.bukalapak.com/c/komputer/laptop?from=nav_header"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
produk = soup.find_all("div", "bl-product-card_description-name")

data = []
for item in produk:
  nama = item.select(".bl.product-card_description-price p")
  price = items.select(".bl-product-card_description-price p")
  data.append({"nama": nama[0].text.strip(), "harga": price[0].text.strip()})

#print(data)
df = pd.DafaFrame(data)
print(df)
